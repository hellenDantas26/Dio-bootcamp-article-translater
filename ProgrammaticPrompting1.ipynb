# %% [markdown]
# <a href="https://colab.research.google.com/github/hellenDantas26/Dio-bootcamp-article-translater/blob/main/ProgrammaticPrompting1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !!pip install litellm

# Important!!!
#
# <---- Set your 'OPENAI_API_KEY' as a secret over there with the "key" icon
#
#
import os
from google.colab import userdata
api_key = userdata.get('OPENAI_API_KEY')   # ← o NOME do segredo')
os.environ['OPENAI_API_KEY']   # ← o NOME do segredo'] = api_key
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_17367/1936853735.py in <cell line: 0>()
#       9 from google.colab import userdata
#      10 api_key = userdata.get('OPENAI_API_KEY')   # ← o NOME do segredo')
# ---> 11 os.environ['OPENAI_API_KEY']   # ← o NOME do segredo'] = api_key
#
# /usr/lib/python3.12/os.py in __getitem__(self, key)
#
# KeyError: 'OPENAI_API_KEY'

# %%
from litellm import completion
from typing import List, Dict


def generate_response(messages: List[Dict]) -> str:
    """Call LLM to get response"""
    response = completion(
        model="openai/gpt-4o",
        messages=messages,
        max_tokens=1024
    )
    return response.choices[0].message.content


messages = [
    {"role": "system", "content": "You are an expert software engineer that prefers functional programming."},
    {"role": "user", "content": "Write a function to swap the keys and values in a dictionary."}
]

response = generate_response(messages)
print(response)
# Out:
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/litellm/llms/openai/openai.py in completion(self, model_response, timeout, optional_params, litellm_params, logging_obj, model, messages, print_verbose, api_key, api_base, api_version, dynamic_params, azure_ad_token, acompletion, logger_fn, headers, custom_prompt_dict, client, organization, custom_llm_provider, drop_params, shared_session)
#     850                     else:
# --> 851                         raise e
#     852         except OpenAIError as e:
#
# ...
